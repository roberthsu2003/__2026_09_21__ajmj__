# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
n = 10
n = n + 1
print(n)
# Out:
# 11

# %%
#複合指定運算子

n = 10
n += 1
n *= 10
print(n)
# Out:
# 110

# %%
#1加到10的總和

m = 0
m += 1
m += 2
m += 3
m += 4
m += 5
m += 6
m += 7
m += 8
m += 9
m += 10
print(f"1加到10的總和是{m}")
# Out:
# 1加到10的總和是55

# %%
print(range(5))
print(range(1,5))
print(range(1,11))
# Out:
# range(0, 5)
# range(1, 5)
# range(1, 11)

# %%
m = 0
for i in range(1,101):
	m += i
print(m)
# Out:
# 5050
