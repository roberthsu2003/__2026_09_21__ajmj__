# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/__2026_09_21__ajmj__/blob/main/0921/0921_lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python")
print("你好! 現在正在上第1節課")
# Out:
# Hello! Python
# 你好! 現在正在上第1節課

# %% [markdown]
# # 這是大標題
# ## 這是次標題
# ### 這是次次標題
#
# 這是第1段文字
#
# 這是第2段文字
#
# ### 下面是項目符號
# - 項目1
# - 項目2
# - 項目3
#
# ### 下面是項目編號
#
# 1. 項目1
# 2. 項目2
# 3. 項目3
