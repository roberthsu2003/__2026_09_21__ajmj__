# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/__2026_09_21__ajmj__/blob/main/0921/0921_lesson3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# 初始設定
principal = 20000
target = 22000
rate = 0.011

# 1 + r
growth_factor = 1 + rate

# 方程式簡化：growth_factor^n = target_ratio
target_ratio = target / principal

# 利用對數求解：n = log(target_ratio) / log(growth_factor)
n = math.log(target_ratio) / math.log(growth_factor)

print(f"存款從 {principal:,} 元增長到 {target:,} 元（年利率 {rate*100}% 複利）")
print(f"需要的時間大約為：{n:.2f} 年")
# Out:
# 存款從 20,000 元增長到 22,000 元（年利率 1.0999999999999999% 複利）
# 需要的時間大約為：8.71 年

# %%
5 < 3

7 >= 10

5 == 5

5 != 5
# Out:
# False

# %%
#單項選擇

age = 17
if age > 18:
  print("大於18")
  print("滿18了")
print("程式結束")
# Out:
# 程式結束

# %%
#雙項選擇

age = 18
if age >= 18:
  print("大於等於18")
  print("可以考駕照了")
else:
  print("小於18")
  print("不可以考駕照了")
print("程式結束")
# Out:
# 大於18
# 可以考駕照了
# 程式結束

# %%
# 巢狀判斷
# 多個條件

furry = False
small = False

if furry:
  if small:
    print("它是貓!")
  else:
    print("它是熊!")
else:
  if small:
    print("它是小蜥蜴")
  else:
    print("它是人類")
# Out:
# 它是人類

# %%
# 可讀性低
score = int(input("請輸入分數:"))
if score >= 90:
  grade = "優"
else:
  if score >= 80:
    grade = "甲"
  else:
    if score >= 70:
      grade = "乙"
    else:
      if score >= 60:
        grade = "丙"
      else:
        grade = "丁"

print(grade)
# Out:
# 請輸入分數:59
# 丁

# %%
# 多項選擇

score = int(input("請輸入分數:"))

if score >= 90:
  grade = "優"
elif score >= 80:
  grade = "甲"
elif score >= 70:
  grade = "乙"
elif score >= 60:
  grade = "丙"
else:
  grade = "丁"

print(grade)
# Out:
# 請輸入分數:59
# 丁

# %%
# BMI 計算與多項選擇判斷

# 1. 取得使用者輸入的身高與體重
height_cm = float(input("請輸入您的身高 (公分): "))
weight_kg = float(input("請輸入您的體重 (公斤): "))

# 2. 將身高轉換為公尺，並計算 BMI
height_m = height_cm / 100
bmi = weight_kg / (height_m ** 2)

# 3. 使用多項選擇判斷體重狀態
if bmi < 18.5:
    status = "體重過輕"
elif bmi < 24:
    status = "健康正常範圍"
elif bmi < 27:
    status = "過重"
elif bmi < 30:
    status = "輕度肥胖"
elif bmi < 35:
    status = "中度肥胖"
else:
    status = "重度肥胖"

# 4. 輸出結果
print(f"您的 BMI 值為: {bmi:.2f}")
print(f"您的體重狀態為: {status}")
# Out:
# 請輸入您的身高 (公分): 183
# 請輸入您的體重 (公斤): 80
# 您的 BMI 值為: 23.89
# 您的體重狀態為: 健康正常範圍
